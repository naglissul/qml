# %% [markdown]
# # Notes on Pennylane tutorial of VQE
#
# [Youtube link](https://www.youtube.com/watch?v=qiRtUUZ5s9s)
#
# Again, not coding up...
#
# Finding the ground state energy of $H_3$ molecule:
#
# 1. Find Hamiltonian
# 2. Prepare ansatz
# 3. Minimize $\langle \hat H \rangle$
#
# ### Hamiltonian
#
# Specifying the molecule geometry (coordinates of Hs) with libraries. Then using other libraries find Hamiltonian.
#
# Gonna need 6 qubits.
#
# ### Ansatz
#
# With library, get the state passing electron number of 2 and orbital number of 6.
#
# [1 1 0 0 0 0] (Jordan-Vignor representation)
#
# > Need to learn more about Jordan-Vignor from chemistry side
#
# Double excitation gate:
#
# ![image.png](attachment:image.png)
#
# Choosing ansatz:
#
# $\alpha |110000\rangle + \beta |001100\rangle + \gamma |000011\rangle$
#
# > Hartri-fox approximation?
#
# > Ritz variational principle - minimized expval IS the ground state
#
# After a lot of calculations...:
#
# $|\psi_0\rangle = 0.9908|110000\rangle - 0.096|001100\rangle - 0.096|000011\rangle$
